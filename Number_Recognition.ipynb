# %% [markdown]
# #Importing the libraries

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# # Load and preprocess the MNIST dataset

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# # Reshape and normalize the data

# %%
x_train = x_train.reshape(x_train.shape[0], 28, 28, 1) / 255.0
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1) / 255.0

# %% [markdown]
# # Convert labels to one-hot encoded format

# %%
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %% [markdown]
# # Build the CNN model

# %%
model = Sequential()

# %% [markdown]
# # Add a convolutional layer with 32 filters, each of size (3, 3), using ReLU activation
# # Input shape: 28x28 grayscale images

# %%
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))

# %% [markdown]
# # Add a max pooling layer to reduce spatial dimensions

# %%
model.add(MaxPooling2D((2, 2)))

# %% [markdown]
# # Add another convolutional layer with 64 filters and ReLU activation

# %%
model.add(Conv2D(64, (3, 3), activation='relu'))

# %% [markdown]
# # Add another max pooling layer

# %%
model.add(MaxPooling2D((2, 2)))

# %% [markdown]
# # Flatten the output from convolutional layers for the fully connected layers

# %%
model.add(Flatten())

# %% [markdown]
# # Add a fully connected layer with 64 units and ReLU activation

# %%
model.add(Dense(64, activation='relu'))

# %% [markdown]
# # Add the final output layer with 10 units (one for each digit) and softmax activation

# %%
model.add(Dense(10, activation='softmax'))

# %% [markdown]
# # Compile the model

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# # Train the model

# %%
model.fit(x_train, y_train, epochs=10, batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/10
# 750/750 [==============================] - 29s 37ms/step - loss: 0.2005 - accuracy: 0.9392 - val_loss: 0.0695 - val_accuracy: 0.9799
# Epoch 2/10
# 750/750 [==============================] - 26s 35ms/step - loss: 0.0609 - accuracy: 0.9809 - val_loss: 0.0538 - val_accuracy: 0.9839
# Epoch 3/10
# 750/750 [==============================] - 26s 35ms/step - loss: 0.0428 - accuracy: 0.9862 - val_loss: 0.0476 - val_accuracy: 0.9862
# Epoch 4/10
# 750/750 [==============================] - 26s 35ms/step - loss: 0.0325 - accuracy: 0.9897 - val_loss: 0.0415 - val_accuracy: 0.9869
# Epoch 5/10
# 750/750 [==============================] - 27s 35ms/step - loss: 0.0257 - accuracy: 0.9912 - val_loss: 0.0463 - val_accuracy: 0.9860
# Epoch 6/10
# 750/750 [==============================] - 26s 34ms/step - loss: 0.0207 - accuracy: 0.9933 - val_loss: 0.0435 - val_accuracy: 0.9872
# Epoch 7/10
# 750/750 [==============================] - 26s 35ms/step - loss: 0.0159 - accuracy: 0.9953 - val_loss: 0.0522 - val_accuracy: 0.9868
# Epoch 8/10
# 750/750 [==============================] - 26s 35ms/step - loss: 0.0131 - accuracy: 0.9957 - val_loss: 0.0457 - val_accuracy: 0.9884
# Epoch 9/10
# 750/750 [==============================] - 26s 35ms/step - loss: 0.0106 - accuracy: 0.9965 - val_loss: 0.0452 - val_accuracy: 0.9887
# Epoch 10/10
# 750/750 [==============================] - 26s 35ms/step - loss: 0.0087 - accuracy: 0.9972 - val_loss: 0.0561 - val_accuracy: 0.9864

# %% [markdown]
# # Evaluate the model on the test set

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Test accuracy:", test_acc)
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 0.0482 - accuracy: 0.9873
# Test accuracy: 0.9872999787330627
